# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # **실습: 단변량 분석 ② - 범주형**

# %% [markdown]
# ## **1. 환경준비**
#
# - 사용할 라이브러리와 분석 대상 데이터를 불러옵니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.simplefilter(action='ignore')
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = (6, 4)

# %%
# CarSeat 데이터
carseat = pd.read_csv('https://raw.githubusercontent.com/Jangrae/csv/master/Carseats.csv')
carseat.drop('Education', axis=1, inplace=True)
carseat.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %% [markdown]
# **📋 데이터 정보**
#
# - Sales: 각 지역 판매량(단위: 1,000개)
# - CompPrice: 경쟁사 가격(단위: 달러)
# - Income: 지역 평균 소득(단위: 1,000달러)
# - Advertising: 각 지역, 회사의 광고 예산(단위: 1,000달러)
# - Population: 지역 인구수(단위: 1,000명)
# - Price: 자사 지역별 판매가격
# - ShelveLoc: 진열상태
# - Age: 지역 인구의 평균 연령
# - Urban: 도심 지역 여부(Yes, No)
# - US: 매장이 미국에 있는지 여부(Yes, No)

# %% [markdown]
# ## **2. 분석**
#
# - carseat 데이터프레임에서 아래 범주형 변수를 다음 방법으로 분석하세요.
#     - 수치화: 범줏값 개수 및 비율
#     - 시각화: sns.countplot() 함수, plt.pie() 함수

# %% [markdown]
# **1️⃣ ShelveLoc**

# %%
# 빈도와 비율
print("ShelveLoc 빈도:")
print(carseat['ShelveLoc'].value_counts())
print("\nShelveLoc 비율:")
print(carseat['ShelveLoc'].value_counts(normalize=True), "\n")
# Out:
# ShelveLoc 빈도:
# ShelveLoc
# Medium    219
# Bad        96
# Good       85
# Name: count, dtype: int64
#
# ShelveLoc 비율:
# ShelveLoc
# Medium    0.5475
# Bad       0.2400
# Good      0.2125
# Name: proportion, dtype: float64

# %%
# 시각화
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.countplot(x='ShelveLoc', data=carseat, palette='Set2')
plt.title("Countplot")

plt.subplot(1,2,2)
carseat['ShelveLoc'].value_counts().plot.pie(autopct="%.1f%%", startangle=90, colors=sns.color_palette("Set2"))
plt.ylabel('')
plt.title("Pie Chart")

plt.show()

# %% [markdown]
# **2️⃣ Urban**

# %%
# 빈도와 비율
print("Urban 빈도:")
print(carseat['Urban'].value_counts())
print("\nUrban 비율:")
print(carseat['Urban'].value_counts(normalize=True), "\n")
# Out:
# Urban 빈도:
# Urban
# Yes    282
# No     118
# Name: count, dtype: int64
#
# Urban 비율:
# Urban
# Yes    0.705
# No     0.295
# Name: proportion, dtype: float64

# %%
# 시각화
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.countplot(x='Urban', data=carseat, palette='Set2')
plt.title("Countplot")

plt.subplot(1,2,2)
carseat['Urban'].value_counts().plot.pie(autopct="%.1f%%", startangle=90, colors=sns.color_palette("Set2"))
plt.ylabel('')
plt.title("Pie Chart")

plt.show()

# %% [markdown]
# **3️⃣ US**

# %%
# 빈도와 비율
print("US 빈도:")
print(carseat['US'].value_counts())
print("\nUS 비율:")
print(carseat['US'].value_counts(normalize=True), "\n")
# Out:
# US 빈도:
# US
# Yes    258
# No     142
# Name: count, dtype: int64
#
# US 비율:
# US
# Yes    0.645
# No     0.355
# Name: proportion, dtype: float64

# %%
# 시각화
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.countplot(x='US', data=carseat, palette='Set2')
plt.title("Countplot")

plt.subplot(1,2,2)
carseat['US'].value_counts().plot.pie(autopct="%.1f%%", startangle=90, colors=sns.color_palette("Set2"))
plt.ylabel('')
plt.title("Pie Chart")

plt.show()
