# %% [markdown]
# **AIVLE School 미니프로젝트**
# ### **VOC를 제기한 고객의 <span style="color:darkgreen">해지 여부</span> 예측 문제**
# ---

# %% [markdown]
# #### **<span style="color:red">[미션 안내]</span>**
# * VOC를 제기한 고객의 데이터를 읽어들여 데이터를 분석 및 전처리한 후 머신러닝과 딥러닝으로 해지 여부를 예측하고 결과를 분석하세요.

# %% [markdown]
# #### **<span style="color:red">[데이터설명]</span>**
# ** 파일명: voc_data.csv
#
#
# -	voc_trt_perd_itg_cd	           : VOC처리기간통합코드
# - voc_prod_sbt_id	               : VOC상품대체아이디
# -	voc_wjt_sorc_id                : VOC업무유형소스아이디
# -	voc_type_itg_cd	               : VOC유형통합코드
# -	voc_sttus_itg_cd               : VOC상태통합코드
# -	voc_trt_reslt_itg_cd	         : VOC처리결과통합코드
# -	cust_pty_sbt_id	               : 고객파티대체아이디
# -	cust_clas_itg_cd	             : 고객등급통합코드
# -	bprod_sbt_id	                 : 기본상품대체아이디
# -	age_itg_cd	                   : 연령 통합 코드
# -	cont_sttus_itg_cd	             : 계약상태통합코드
# -	new_date	                     : 신규일자
# -	opn_nfl_chg_date	             : 개통명의변경일자
# -	cust_dtl_ctg_itg_cd	           : 고객상세분류통합코드
# -	voc_trt_degr_div_itg_cd	       : VOC처리차수구분통합코드
# -	voc_dupl_tmscnt        	       : VOC중복횟수
# -	oos_cause_type_itg_cd	         : 고장원인유형통합코드
# -	voc_trt_need_time_itg_cd       : VOC처리소요시간통합코드
# -	engt_cperd_type_itg_cd	       : 약정계약기간유형통합코드
# -	engt_tgt_div_itg_cd	           : 약정대상구분통합코드
# -	cont_fns_pam_date	             : 계약종료예정일자
# -	voc_mis_pbls_yn	               : VOC오발행여부
# -	fclt_oos_yn                  	 : 시설고장여부
# -	cust_snsry_base_conf_need_time : 고객체감기준확인소요시간
# -	trm_yn	                       : 고객해지 여부

# %% [markdown]
# #### **<span style="color:red">[유의 사항]</span>**
# * 각 문항의 답안코드는 반드시 '#여기에 답안코드를 작성하세요'로 표시된 cell에 작성해야 합니다.
# * 제공된 cell을 추가/삭제하고 다른 cell에 답안코드를 작성 시 채점되지 않습니다.
# * 반드시 문제에 제시된 가이드를 읽고 답안 작성하세요.
# * 문제에 변수명이 제시된 경우 반드시 해당 변수명을 사용하세요.
# * 문제와 데이터는 제3자에게 공유하거나 개인적인 용도로 사용하는 등 외부로 유출할 수 없으며 유출로 인한 책임은 응시자 본인에게 있습니다.

# %%
# 코드실행시 경고 메시지 무시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# <br>

# %% [markdown]
# ## **<span style="">1. 필요한 라이브러리 설치</span>**

# %% [markdown]
# <Br>
# <font >1-1. pip 이용해서 seaborn을 설치하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
# !pip install seaborn

# %% [markdown]
# <br>
# <font >1-2. numpy 별칭을 np로, pandas 별칭을 pd로 해서 임포트 하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
import pandas as pd

# %% [markdown]
# <br>
# <font >1-3. matplotlib 라이브러리를 plt로, seaborn을 sns로 해서 임포트 하세요

# %%
# 여기에 답안코드를 작성하세요.
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br>

# %% [markdown]
# ## **<span style="">2. Tabular 데이터 로딩</span>**

# %% [markdown]
# <br>
# <font >2-1. pandas read_csv 함수를 사용하여 voc_data.csv 파일을 읽어온 후 df에 저장하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
df = pd.read_csv('./data/voc_data.csv')

# %% [markdown]
# <br>

# %% [markdown]
# ## **<span style="">3. 데이터의 구성 확인</span>**

# %% [markdown]
# <br>
# <font >3-1. "df" DataFrame 이용해서 읽어들인 파일의 앞부분 5줄, 뒷부분 5줄을 출력하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df.head()
# Out:
#   voc_trt_perd_itg_cd  voc_prod_sbt_id  voc_wjt_sorc_id  voc_type_itg_cd  \
# 0                   _       1000665328             2153            10009
# 1                   _       1001028714             3311            10009
# 2                   _       1001028567             1575            10009
# 3               10000       1000665328             3546            10009
# 4                   _       1000779276             3086            10009
#
#    voc_sttus_itg_cd voc_trt_reslt_itg_cd cust_clas_itg_cd  bprod_sbt_id  \
# 0             10002                    _                F    1000001126
# 1             10002                10081                G    1000852226
# 2             10002                    _                G    1000851875
# 3             10002                    _                _    1000001126
# 4             10002                    _                G    1000764639
#
#   age_itg_cd cont_sttus_itg_cd  ...  voc_dupl_tmscnt  oos_cause_type_itg_cd  \
# ...

# %%
# 여기에 답안코드를 작성하세요.
df.tail()
# Out:
#      voc_trt_perd_itg_cd  voc_prod_sbt_id  voc_wjt_sorc_id  voc_type_itg_cd  \
# 9995                   _       1000811136             2123            10009
# 9996                   _       1001047799             2153            10009
# 9997                   _       1001027819              379            10009
# 9998                   _       1001027819              314            10009
# 9999                   _       1001047802             2266            10009
#
#       voc_sttus_itg_cd voc_trt_reslt_itg_cd cust_clas_itg_cd  bprod_sbt_id  \
# 9995             10002                    _                G    1000809259
# 9996             10002                    _                I    1001046521
# 9997             10002                    _                G    1000720809
# 9998             10002                    _                I    1000720809
# 9999             10002                    _                G    1001046524
#
# ...

# %% [markdown]
# <br>
# <font >3-2. 데이터프레임 정보(컬럼정보, Null 여부, 타입) 출력하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   voc_trt_perd_itg_cd             10000 non-null  object
#  1   voc_prod_sbt_id                 10000 non-null  int64
#  2   voc_wjt_sorc_id                 10000 non-null  int64
#  3   voc_type_itg_cd                 10000 non-null  int64
#  4   voc_sttus_itg_cd                10000 non-null  int64
#  5   voc_trt_reslt_itg_cd            10000 non-null  object
#  6   cust_clas_itg_cd                10000 non-null  object
#  7   bprod_sbt_id                    10000 non-null  int64
#  8   age_itg_cd                      10000 non-null  object
#  9   cont_sttus_itg_cd               10000 non-null  object
#  10  new_date                        10000 non-null  int64
#  11  opn_nfl_chg_date                10000 non-null  int64
# ...

# %% [markdown]
# <br>
# <font >3-3. 데이터프레임 인덱스를 확인하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %% [markdown]
# <br>
# <font >3-4. 데이터프레임 컬럼을 확인하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df.columns
# Out:
# Index(['voc_trt_perd_itg_cd', 'voc_prod_sbt_id', 'voc_wjt_sorc_id',
#        'voc_type_itg_cd', 'voc_sttus_itg_cd', 'voc_trt_reslt_itg_cd',
#        'cust_clas_itg_cd', 'bprod_sbt_id', 'age_itg_cd', 'cont_sttus_itg_cd',
#        'new_date', 'opn_nfl_chg_date', 'cust_dtl_ctg_itg_cd',
#        'voc_trt_degr_div_itg_cd', 'voc_dupl_tmscnt', 'oos_cause_type_itg_cd',
#        'voc_trt_need_time_itg_cd', 'engt_cperd_type_itg_cd',
#        'engt_tgt_div_itg_cd', 'cont_fns_pam_date', 'voc_mis_pbls_yn',
#        'fclt_oos_yn', 'cust_snsry_base_conf_need_time', 'trm_yn'],
#       dtype='object')

# %% [markdown]
# <br>
# <font >3-5. 데이터프레임 값(value)을 확인하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df.values
# Out:
# array([['_', 1000665328, 2153, ..., '_', 0, 'N'],
#        ['_', 1001028714, 3311, ..., '_', 0, 'N'],
#        ['_', 1001028567, 1575, ..., 'N', 0, 'N'],
#        ...,
#        ['_', 1001027819, 379, ..., 'N', 0, 'N'],
#        ['_', 1001027819, 314, ..., '_', 0, 'N'],
#        ['_', 1001047802, 2266, ..., '_', 0, 'N']], dtype=object)

# %% [markdown]
# <br>
# <font >3-6. 데이터프레임의 계산 가능한 값들에 대한 통계치를 확인하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df.describe()
# Out:
#        voc_prod_sbt_id  voc_wjt_sorc_id  voc_type_itg_cd  voc_sttus_itg_cd  \
# count     1.000000e+04      10000.00000      10000.00000      10000.000000
# mean      9.907267e+08       1578.29170      10008.52360      10002.043400
# std       1.005780e+08       1078.63717          1.57927          0.314843
# min      -9.980000e+02        126.00000      10003.00000      10002.000000
# 25%       1.000782e+09        360.00000      10009.00000      10002.000000
# 50%       1.001028e+09       2056.00000      10009.00000      10002.000000
# 75%       1.001036e+09       2153.00000      10009.00000      10002.000000
# max       1.001079e+09       3856.00000      10017.00000      10005.000000
#
#        bprod_sbt_id      new_date  opn_nfl_chg_date  voc_trt_degr_div_itg_cd  \
# count  1.000000e+04  1.000000e+04      1.000000e+04             10000.000000
# mean   8.838173e+08  1.744283e+07      1.744505e+07             20001.074200
# ...

# %% [markdown]
# <br>
# <font >3-7. DataFrame 컬럼 항목에 Null 존재하는지 확인하세요.  (null값의 합계 포함)</font>

# %%
# 여기에 답안코드를 작성하세요.
df.isnull().sum()
# Out:
# voc_trt_perd_itg_cd               0
# voc_prod_sbt_id                   0
# voc_wjt_sorc_id                   0
# voc_type_itg_cd                   0
# voc_sttus_itg_cd                  0
# voc_trt_reslt_itg_cd              0
# cust_clas_itg_cd                  0
# bprod_sbt_id                      0
# age_itg_cd                        0
# cont_sttus_itg_cd                 0
# new_date                          0
# opn_nfl_chg_date                  0
# cust_dtl_ctg_itg_cd               0
# voc_trt_degr_div_itg_cd           0
# voc_dupl_tmscnt                   0
# oos_cause_type_itg_cd             0
# voc_trt_need_time_itg_cd          0
# engt_cperd_type_itg_cd            0
# engt_tgt_div_itg_cd               0
# cont_fns_pam_date                 0
# voc_mis_pbls_yn                   0
# fclt_oos_yn                       0
# cust_snsry_base_conf_need_time    0
# trm_yn                            0
# dtype: int64

# %% [markdown]
# <br>
# <font >3-8. voc_trt_perd_itg_cd 컬럼의 데이터를 확인하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df['voc_trt_perd_itg_cd']
# Out:
# 0           _
# 1           _
# 2           _
# 3       10000
# 4           _
#         ...
# 9995        _
# 9996        _
# 9997        _
# 9998        _
# 9999        _
# Name: voc_trt_perd_itg_cd, Length: 10000, dtype: object

# %% [markdown]
# <br>
# <font >3-9. voc_trt_perd_itg_cd 컬럼 데이터별 건수를 나열하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
df['voc_trt_perd_itg_cd'].value_counts()
# Out:
# voc_trt_perd_itg_cd
# _        5422
# 10000    4283
# 10001     163
# 10002      58
# 10003      25
# 10004      16
# 10005      10
# 10006       6
# 10008       3
# 10009       3
# 10016       2
# 10011       2
# 10012       2
# 10007       2
# 10014       1
# 10013       1
# 10015       1
# Name: count, dtype: int64

# %% [markdown]
# ### 컬럼에서  '_' 값이 차지하는 비율
# - voc_trt_perd_itg_cd : 0.54
# - voc_trt_reslt_itg_cd : 0.88
# - oos_cause_type_itg_cd : 0.9
# - engt_cperd_type_itg_cd : 0.63
# - engt_tgt_div_itg_cd : 0.63
# - fclt_oos_yn : 0.90
# - cust_clas_itg_cd : 0.2
# - age_itg_cd : 0.22
# - cont_sttus_itg_cd : 0.11
# - cust_dtl_ctg_itg_cd : 0.11
# - voc_mis_pbls_yn : 0.008

# %% [markdown]
# ## **<span style="">4. 데이터 결측치 처리</span>**

# %% [markdown]
# <br>
# <font >4-1. voc_trt_perd_itg_cd 컬럼에서 '_' 값이 차지하는 비율이 50%가 넘는 것을 확인하고, 이 voc_trt_perd_itg_cd 컬럼을 삭제하세요. (컬럼이 삭제된 데이터를 df1에 저장하세요)</font>

# %%
# 여기에 답안코드를 작성하세요.
ratio = (df['voc_trt_perd_itg_cd'] == '_').mean()
print(ratio)
df1 = df.drop(columns=['voc_trt_perd_itg_cd'])
# Out:
# 0.5422

# %% [markdown]
# <br>
# <font >4-2. 'df1' DataFrame에서 '_' 값이 50% 이상되는 나머지 컬럼도 삭제하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
underscore_ratio = (df1 == '_').mean()
cols_drop = underscore_ratio[underscore_ratio >= 0.5].index
df1 = df1.drop(columns=cols_drop)

# %% [markdown]
# <br>
# <font >4-3. 'df1' DataFrame의 'cust_clas_itg_cd' 컬럼에 '_' 값이 몇 개 있는지 확인하여 출력하세요 </font>

# %%
# 여기에 답안코드를 작성하세요.
(df1['cust_clas_itg_cd'] == '_').sum()
# Out:
# 1934

# %% [markdown]
# <br>
# <font >4-4. df1의 남아있는 '_'값을 null로 변경: DataFrame replace 함수를 사용해서 모든 컬럼에 대해 '_'값을 null로 변경하고 df2에 저장하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
import numpy as np
df2 = df1.replace('_', np.nan)

# %% [markdown]
# <br>
# <font >4-5. df2의 컬럼별 Null 갯수를 확인해보세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
df2.isnull().sum()
# Out:
# voc_prod_sbt_id                      0
# voc_wjt_sorc_id                      0
# voc_type_itg_cd                      0
# voc_sttus_itg_cd                     0
# cust_clas_itg_cd                  1934
# bprod_sbt_id                         0
# age_itg_cd                        2129
# cont_sttus_itg_cd                 1168
# new_date                             0
# opn_nfl_chg_date                     0
# cust_dtl_ctg_itg_cd               1168
# voc_trt_degr_div_itg_cd              0
# voc_dupl_tmscnt                      0
# voc_trt_need_time_itg_cd             0
# cont_fns_pam_date                    0
# voc_mis_pbls_yn                     86
# cust_snsry_base_conf_need_time       0
# trm_yn                               0
# dtype: int64

# %% [markdown]
# <br>
# <font >4-6. df2 데이터프레임 컬럼들의 데이터타입을 확인하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   voc_prod_sbt_id                 10000 non-null  int64
#  1   voc_wjt_sorc_id                 10000 non-null  int64
#  2   voc_type_itg_cd                 10000 non-null  int64
#  3   voc_sttus_itg_cd                10000 non-null  int64
#  4   cust_clas_itg_cd                8066 non-null   object
#  5   bprod_sbt_id                    10000 non-null  int64
#  6   age_itg_cd                      7871 non-null   object
#  7   cont_sttus_itg_cd               8832 non-null   object
#  8   new_date                        10000 non-null  int64
#  9   opn_nfl_chg_date                10000 non-null  int64
#  10  cust_dtl_ctg_itg_cd             8832 non-null   object
#  11  voc_trt_degr_div_itg_cd         10000 non-null  int64
# ...

# %% [markdown]
# <br>
# <font >4-7. df2 데이터프레임에 대해 먼저, 'cust_clas_itg_cd' 컬럼의 최빈값을 확인하는 코드로 확인하고 다음으로, 이 컬럼의 Null 값을 최빈값으로 변경하세요(fillna 함수 사용). 처리된 데이터프레임은 df3에 저장하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
temp = df2['cust_clas_itg_cd'].value_counts().index[0]
df3 = df2.copy()
df3['cust_clas_itg_cd'] = df3['cust_clas_itg_cd'].fillna(temp)

# %% [markdown]
# <br>
# <font >4-8. df3에 대해 'age_itg_cd'의 데이터 타입을 정수로(int)변경하고, null 값을 중앙값(median)으로 변경하세요. 데이터 처리 후 데이터프레임을 df4에 저장하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
df4 = df3.copy()
df4['age_itg_cd'] = pd.to_numeric(df4['age_itg_cd'])

median = df4['age_itg_cd'].median()
df4['age_itg_cd'] = df4['age_itg_cd'].fillna(median)

# %% [markdown]
# <br>
# <font >4-9. df4에 대해 'cont_sttus_itg_cd'의 null 값을 최빈값(mode)으로 변경하세요. 데이터 처리 후 데이터프레임을 df5에 저장하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
mode = df4['cont_sttus_itg_cd'].value_counts().index[0]
df5 = df4.copy()
df5['cont_sttus_itg_cd'] = df5['cont_sttus_itg_cd'].fillna(mode)

# %% [markdown]
# <br>
# <font >4-10. df5에 대해 'cust_dtl_ctg_itg_cd'의 null 값을 최빈값(mode)으로 변경하세요</font>

# %%
# 여기에 답안코드를 작성하세요.
mode = df5['cust_dtl_ctg_itg_cd'].value_counts().index[0]
df5['cust_dtl_ctg_itg_cd'] = df5['cust_dtl_ctg_itg_cd'].fillna(mode)

# %% [markdown]
# <br>
# <font >4-11. df5에 대해 다음 날짜 관련 컬럼을 확인 후 삭제하세요. (날짜 관련 컬럼: new_date, opn_nfl_chg_date, cont_fns_pam_date)</font>

# %%
# 여기에 답안코드를 작성하세요.
cols = ["new_date", "opn_nfl_chg_date", "cont_fns_pam_date"]
for c in cols:
    display(df5[c].head())
df5 = df5.drop(columns=cols)
# Out:
# 0    19881005
# 1    20130817
# 2    20190509
# 3    20190731
# 4    20180403
# Name: new_date, dtype: int64
# 0    19881005
# 1    20130817
# 2    20190509
# 3    20190731
# 4    20180403
# Name: opn_nfl_chg_date, dtype: int64
# 0    99991231
# 1    20220319
# 2    20220508
# 3    99991231
# 4    99991231
# Name: cont_fns_pam_date, dtype: int64

# %% [markdown]
# <br>
# <font >4-12. df5에 대해 'voc_mis_pbls_yn' 컬럼을 삭제하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
df5 = df5.drop(columns=['voc_mis_pbls_yn'])

# %% [markdown]
# ## **<span style="">5. 라벨 인코딩, 원핫 인코딩</span>**

# %% [markdown]
# <br>
# <font >5-1. df5에 대해 object 타입 컬럼을 cat_cols에 저장하세요. 그 중 cat_cols의 cust_clas_itg_cd 컬럼에 대해 LabelEncoder를 적용해보세요. (적용 후 df5에 저장)</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.preprocessing import LabelEncoder

cat_cols = df5.select_dtypes(include='object').columns
display(cat_cols)

label_encoder = LabelEncoder()
df5['cust_clas_itg_cd'] = label_encoder.fit_transform(df5['cust_clas_itg_cd'])
# Out:
# Index(['cust_clas_itg_cd', 'cont_sttus_itg_cd', 'cust_dtl_ctg_itg_cd',
#        'trm_yn'],
#       dtype='object')

# %% [markdown]
# <br>
# <font >5-2. df5의 나머지 object 컬럼에 대해서 One-Hot Encoding될수 있도록 Pandas의 get_dummies 함수를 적용하세요. (적용 후 df6에 저장)</font>

# %%
# 여기에 답안코드를 작성하세요.
df6 = pd.get_dummies(df5, drop_first=True)

# %% [markdown]
# ## **<span style="">6. x,y 데이터 분리</span>**

# %% [markdown]
# <br>
# <font >6-1. df6에 대해 X, y 값을 가지고 8:2 비율로 Train , Test Dataset으로 나누세요. (y 클래스 비율에 맞게 분리, y 값은 'trm_yn_Y' 컬럼, random_state는 42)</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.model_selection import train_test_split

X = df6.drop(columns=['trm_yn_Y'])
y = df6['trm_yn_Y']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2, stratify=y)

# %% [markdown]
# <br>

# %% [markdown]
# ## **<span style="">7. 데이터 정규분포화, 표준화</span>**

# %% [markdown]
# <br>
# <font >7-1. 사이킷런의 StandardScaler로 훈련데이터셋은 정규분포화(fit_transform)하고 테스트 데이터셋은 표준화(transform)하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## **<span style="">8. 머신러닝 모델링 & 모델 성능평가 및 그래프 출력</span>**

# %% [markdown]
# ### 로지스틱 회귀 (LogisticRegression, 분류)

# %% [markdown]
# <br>
# <font >8-1. LogisticRegression 모델을 만들고 학습을 진행하세요 (단, 규제강도C는 10으로 설정, 계산에 사용할 작업수 max_iter는 2000으로 설정하세요)</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=2000, C=10)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=2000)

# %% [markdown]
# <br>
# <font >8-2. 위 모델의 성능을 평가하려고 합니다. y값을 예측하여 confusion matrix를 구하고 heatmap 그래프로 시각화하세요. 그리고 Scikit-learn의 classification_report를 활용하여 성능을 출력하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

y_pred = model.predict(X_test)
cof = confusion_matrix(y_test, y_pred)

plt.imshow(cof)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
for i in range(cof.shape[0]):
    for j in range(cof.shape[1]):
        plt.text(j, i, cof[i, j], ha='center', va='center', color='black')
plt.show()

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      1955
#         True       0.50      0.02      0.04        45
#
#     accuracy                           0.98      2000
#    macro avg       0.74      0.51      0.52      2000
# weighted avg       0.97      0.98      0.97      2000

# %% [markdown]
# <br>
# <font >8-3. DecisionTree 모델을 만들고 학습을 진행하세요. (단, max_depth는 10, random_state는 42로 설정)</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=1, random_state=42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=1, random_state=42)

# %% [markdown]
# <br>
# <font >8-4. RandomForest 모델을 만들고 학습을 진행하세요. (단, n_estimators=100, random_state=42 설정)</font>

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# <br>
# <font >8-5. XGBoost 모델을 만들고 학습을 진행하세요. (단, n_estimators=5 설정)</font>

# %%
# 여기에 답안코드를 작성하세요.
from xgboost import XGBRegressor

xg = XGBRegressor(n_estimators=5)
xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=5,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# <br>
# <font >8-6. Light GBM 모델을 만들고 학습을 진행하세요. (단, n_estimators=3 설정)</font>

# %%
# 여기에 답안코드를 작성하세요.
import lightgbm as lgb

gbm = lgb.LGBMRegressor(n_estimators=3)
gbm.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000369 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 795
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 24
# [LightGBM] [Info] Start training from score 0.022375
# LGBMRegressor(n_estimators=3)

# %% [markdown]
# <br>
# <font >8-7. Linear Regression 모델을 연습으로 만들고 학습을 진행하세요.</font>

# %%
# 이 데이터로 연습하세요.
x_data = np.array([1.6, 2.3, 3.5, 4.6]).reshape(-1,1)
y_data = np.array([3.3, 5.5, 7.2, 9.9])

# %%
# 여기에 답안코드를 작성하세요.
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(x_data, y_data)
# Out:
# LinearRegression()

# %% [markdown]
# <br>

# %% [markdown]
# ## **<span style="">9. 딥러닝 모델링 & 모델 성능평가 및 그래프 출력</span>**

# %% [markdown]
# <br>
# <font >9-1. 아래 가이드대로 해지여부를 분류하는 딥러닝 모델을 만드세요.</font>

# %% [markdown]
# + 첫번째 Hidden Layer : unit 64 , activation='relu'
# + 두번째 Hidden Layer : unit 32 , activation='relu'
# + 세번째 Hidden Layer : unit 16 , activation='relu'
# + 각 Hidden Layer 마다 Dropout 0.2 비율로 되도록 하세요.
# + EarlyStopping 콜백을 적용하고 ModelCheckpoint 콜백으로 validation performance가 좋은 모델을 best_model.keras 모델로 저장하세요.
# + batch_size는 10, epochs는 10으로 설정하세요.

# %%
# 여기에 답안코드를 작성하세요.
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1])),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

estop = EarlyStopping()
checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_loss',
    save_best_only=True
)

model.compile(optimizer=Adam(), loss='mse')
model.fit(
    X_train,
    y_train,
    batch_size=10,
    epochs=10,
    callbacks=[estop, checkpoint]
)
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step - loss: 0.0374
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 754us/step - loss: 0.0223
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step - loss: 0.0221
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - loss: 0.0213
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - loss: 0.0217
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step - loss: 0.0208
# Epoch 7/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 756us/step - loss: 0.0211
# Epoch 8/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - loss: 0.0209
# Epoch 9/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - loss: 0.0208
# Epoch 10/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 758us/step - loss: 0.0204

# %% [markdown]
# <br>
# <font >9-2. y_train, y_test를 원핫 인코딩 후 다중 분류하는 딥러닝 모델을 만드세요. 9-1과 동일한 가이드 적용</font>

# %%
# 여기에 답안코드를 작성하세요.
y_train_onehot = pd.get_dummies(y_train)
y_test_onehot = pd.get_dummies(y_test)

# %%
# 참고
# Y 레이블 One-Hot-Encoding 되지 않았으면 loss='sparse_categorical_crossentropy' 사용
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['acc'])
# history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, callbacks=[es,mc], validation_data=(X_test, y_test), verbose=1)

model2 = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(y_train_onehot.shape[1], activation='softmax') 
])

estop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_loss',
    save_best_only=True
)

model2.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

history = model2.fit(
    X_train,
    y_train_onehot,
    validation_data=(X_test, y_test_onehot),
    batch_size=10,
    epochs=10,
    callbacks=[estop, checkpoint]
).history
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9689 - loss: 0.1567 - val_accuracy: 0.9775 - val_loss: 0.0894
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9776 - loss: 0.1065 - val_accuracy: 0.9775 - val_loss: 0.0888
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9776 - loss: 0.0974 - val_accuracy: 0.9770 - val_loss: 0.0884
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9779 - loss: 0.0949 - val_accuracy: 0.9775 - val_loss: 0.0911
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9776 - loss: 0.0956 - val_accuracy: 0.9770 - val_loss: 0.0920
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9774 - loss: 0.0927 - val_accuracy: 0.9775 - val_loss: 0.0882
# Epoch 7/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9780 - loss: 0.0898 - val_accuracy: 0.9775 - val_loss: 0.0912
# Epoch 8/10
# ...

# %% [markdown]
# <br>
# <font >9-3. 모델 성능을 평가해서 그래프로 표현하세요. 학습 정확도와 검증정확도를 그래프로 표시하고 xlabel에는 Epochs, ylabel에는 Accuracy, 범례에는 Train과 Validation으로 표시하세요..</font>

# %%
# 여기에 답안코드를 작성하세요.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Train', 'Validation'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step

# %% [markdown]
# <br>
# <font >9-4. 모델 성능을 평가해서 그래프로 표현하세요. 학습 손실과 검증 손실을 그래프로 표시하고 xlabel에는 Epochs, ylabel에는 Loss, 범례에는 Train Loss와 Validation Loss로 표시하세요.</font>

# %%
# 여기에 답안코드를 작성하세요.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train Loss', 'Validation Loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# <br>
# <font >9-5. y값을 예측하여 y_test_pred에 저장하고 정확도를 출력하세요..</font>

# %%
# 여기에 답안코드를 작성하세요.
y_test_pred = model2.predict(X_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step

# %%
from sklearn.metrics import accuracy_score
print(f"Accuracy Score: {accuracy_score(y_test, y_test_pred)}")
# Out:
# Accuracy Score: 0.9775
