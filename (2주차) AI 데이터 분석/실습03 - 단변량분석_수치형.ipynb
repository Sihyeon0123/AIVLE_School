# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # **실습: 단변량 분석 ① - 수치형**

# %% [markdown]
# ## **1. 환경준비**
#
# - 사용할 라이브러리와 분석 대상 데이터를 불러옵니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.simplefilter(action='ignore')
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = (6, 4)

# %%
# CarSeat 데이터
carseat = pd.read_csv('https://raw.githubusercontent.com/Jangrae/csv/master/Carseats.csv')
carseat.drop('Education', axis=1, inplace=True)
carseat.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %% [markdown]
# **📋 데이터 정보**
#
# - Sales: 각 지역 판매량(단위: 1,000개)
# - CompPrice: 경쟁사 가격(단위: 달러)
# - Income: 지역 평균 소득(단위: 1,000달러)
# - Advertising: 각 지역, 회사의 광고 예산(단위: 1,000달러)
# - Population: 지역 인구수(단위: 1,000명)
# - Price: 자사 지역별 판매가격
# - ShelveLoc: 진열상태
# - Age: 지역 인구의 평균 연령
# - Urban: 도심 지역 여부(Yes, No)
# - US: 매장이 미국에 있는지 여부(Yes, No)

# %% [markdown]
# ## **2. 분석**
#
# - carseat 데이터프레임의 다음 변수들에 대해 기초 통계량과 시각화로 데이터를 분석하세요.
# - 시각화는 sns.histplot(), sns.kdeplot(), sns.boxplot() 함수를 사용하세요.
# - 시각화는 plt.subplot() 함수를 사용해 1행 3열로 세 개의 그래프를 같이 표현해 보세요.

# %% [markdown]
# **1️⃣ Sales**

# %%
plt.figure(figsize=(18, 5))

# Histogram
plt.subplot(1, 3, 1)
sns.histplot(carseat['Sales'])
plt.title("Histogram")

# KDE
plt.subplot(1, 3, 2)
sns.kdeplot(carseat['Sales'])
plt.title("KDE Plot")

# Boxplot
plt.subplot(1, 3, 3)
sns.boxplot(x=carseat['Sales'])
plt.title("Boxplot")

plt.suptitle("Sales", fontsize=16, y=1.05)
plt.show()

# %% [markdown]
# **2️⃣ Income**

# %%
plt.figure(figsize=(18, 5))

# Histogram
plt.subplot(1, 3, 1)
sns.histplot(carseat['Income'])
plt.title("Histogram")

# KDE
plt.subplot(1, 3, 2)
sns.kdeplot(carseat['Income'])
plt.title("KDE Plot")

# Boxplot
plt.subplot(1, 3, 3)
sns.boxplot(x=carseat['Income'])
plt.title("Boxplot")

plt.suptitle("Income", fontsize=16, y=1.05)
plt.show()

# %% [markdown]
# **3️⃣ Price**

# %%
plt.figure(figsize=(18, 5))

# Histogram
plt.subplot(1, 3, 1)
sns.histplot(carseat['Price'])
plt.title("Histogram")

# KDE
plt.subplot(1, 3, 2)
sns.kdeplot(carseat['Price'])
plt.title("KDE Plot")

# Boxplot
plt.subplot(1, 3, 3)
sns.boxplot(x=carseat['Price'])
plt.title("Boxplot")

plt.suptitle("Price", fontsize=16, y=1.05)
plt.show()

# %% [markdown]
# **4️⃣ Age**

# %%
plt.figure(figsize=(18, 5))

# Histogram
plt.subplot(1, 3, 1)
sns.histplot(carseat['Age'])
plt.title("Histogram")

# KDE
plt.subplot(1, 3, 2)
sns.kdeplot(carseat['Age'])
plt.title("KDE Plot")

# Boxplot
plt.subplot(1, 3, 3)
sns.boxplot(x=carseat['Age'])
plt.title("Boxplot")

plt.suptitle("Age", fontsize=16, y=1.05)
plt.show()
